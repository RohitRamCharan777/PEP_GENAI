# %%
# Out:
# Running cells with 'virtual (Python 3.14.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/Downloads/genAIML/virtual/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
